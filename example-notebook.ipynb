# %% [markdown]
# # Basic Example of Running Dask with a Local Cluster

# %% [markdown]
# ## Imports

# %%
from dask.array import array
from distributed import LocalCluster, Client

# %% [markdown]
# ## Spin Up a Cluster/Client

# %%
cluster = LocalCluster()
client = Client(cluster)
client
# Out:
# <Client: 'tcp://127.0.0.1:58251' processes=5 threads=10, memory=32.00 GiB>

# %% [markdown]
# ## Your Analysis
# Let's create a sample calculation - an array of numbers, and take a summation.

# %%
array(([1, 2, 3])).sum().compute()
# Out:
# 6
